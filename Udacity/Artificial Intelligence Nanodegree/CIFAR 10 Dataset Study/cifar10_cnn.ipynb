# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=20,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
#  - 9s - loss: 0.9998 - acc: 0.6631 - val_loss: 1.1106 - val_acc: 0.6276
#
# Epoch 00001: val_loss improved from inf to 1.11061, saving model to model.weights.best.hdf5
# Epoch 2/20
#  - 9s - loss: 1.0121 - acc: 0.6607 - val_loss: 1.0203 - val_acc: 0.6654
#
# Epoch 00002: val_loss improved from 1.11061 to 1.02031, saving model to model.weights.best.hdf5
# Epoch 3/20
#  - 9s - loss: 1.0231 - acc: 0.6601 - val_loss: 1.2225 - val_acc: 0.5952
#
# Epoch 00003: val_loss did not improve from 1.02031
# Epoch 4/20
#  - 9s - loss: 1.0289 - acc: 0.6587 - val_loss: 0.8706 - val_acc: 0.7086
#
# Epoch 00004: val_loss improved from 1.02031 to 0.87064, saving model to model.weights.best.hdf5
# Epoch 5/20
#  - 9s - loss: 1.0500 - acc: 0.6508 - val_loss: 1.2630 - val_acc: 0.5732
#
# Epoch 00005: val_loss did not improve from 0.87064
# Epoch 6/20
#  - 9s - loss: 1.0605 - acc: 0.6499 - val_loss: 1.0289 - val_acc: 0.6576
#
# Epoch 00006: val_loss did not improve from 0.87064
# Epoch 7/20
#  - 9s - loss: 1.0690 - acc: 0.6451 - val_loss: 0.9903 - val_acc: 0.6730
#
# Epoch 00007: val_loss did not improve from 0.87064
# Epoch 8/20
#  - 9s - loss: 1.0854 - acc: 0.6430 - val_loss: 1.0713 - val_acc: 0.6360
#
# Epoch 00008: val_loss did not improve from 0.87064
# Epoch 9/20
#  - 9s - loss: 1.0916 - acc: 0.6411 - val_loss: 1.1278 - val_acc: 0.6228
#
# Epoch 00009: val_loss did not improve from 0.87064
# Epoch 10/20
#  - 9s - loss: 1.1130 - acc: 0.6327 - val_loss: 1.1817 - val_acc: 0.5874
#
# Epoch 00010: val_loss did not improve from 0.87064
# Epoch 11/20
#  - 9s - loss: 1.1253 - acc: 0.6299 - val_loss: 1.3858 - val_acc: 0.5802
#
# Epoch 00011: val_loss did not improve from 0.87064
# Epoch 12/20
#  - 9s - loss: 1.1446 - acc: 0.6240 - val_loss: 1.1682 - val_acc: 0.6538
#
# Epoch 00012: val_loss did not improve from 0.87064
# Epoch 13/20
#  - 9s - loss: 1.1558 - acc: 0.6203 - val_loss: 0.9683 - val_acc: 0.6864
#
# Epoch 00013: val_loss did not improve from 0.87064
# Epoch 14/20
#  - 9s - loss: 1.1709 - acc: 0.6134 - val_loss: 1.3576 - val_acc: 0.6230
#
# Epoch 00014: val_loss did not improve from 0.87064
# Epoch 15/20
#  - 9s - loss: 1.1857 - acc: 0.6127 - val_loss: 1.0982 - val_acc: 0.6334
#
# Epoch 00015: val_loss did not improve from 0.87064
# Epoch 16/20
#  - 9s - loss: 1.1962 - acc: 0.6083 - val_loss: 1.5270 - val_acc: 0.4508
#
# Epoch 00016: val_loss did not improve from 0.87064
# Epoch 17/20
#  - 9s - loss: 1.2089 - acc: 0.6006 - val_loss: 1.4505 - val_acc: 0.5740
#
# Epoch 00017: val_loss did not improve from 0.87064
# Epoch 18/20
#  - 9s - loss: 1.2280 - acc: 0.5979 - val_loss: 1.1898 - val_acc: 0.6004
#
# Epoch 00018: val_loss did not improve from 0.87064
# Epoch 19/20
#  - 9s - loss: 1.2361 - acc: 0.5928 - val_loss: 1.1613 - val_acc: 0.6110
#
# Epoch 00019: val_loss did not improve from 0.87064
# Epoch 20/20
#  - 9s - loss: 1.2438 - acc: 0.5925 - val_loss: 1.0032 - val_acc: 0.6572
#
# Epoch 00020: val_loss did not improve from 0.87064

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6957

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))

# %% [markdown]
# ### 11. Creating new model Model_1

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.callbacks import ModelCheckpoint   

model_1 = Sequential()
model_1.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', input_shape=(32, 32, 3)))
model_1.add(MaxPooling2D(pool_size=2))
model_1.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model_1.add(MaxPooling2D(pool_size=2))
model_1.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model_1.add(MaxPooling2D(pool_size=2))
model_1.add(Dropout(0.3))
model_1.add(Flatten())
model_1.add(Dense(500, activation='relu'))
model_1.add(Dropout(0.4))
model_1.add(Dense(256, activation='relu'))
model_1.add(Dropout(0.4))
model_1.add(Dense(10, activation='softmax'))

model_1.summary()

# compile the model_1
model_1.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# train the model_1
checkpointer = ModelCheckpoint(filepath='model_1_CNN.hdf5', verbose=1, save_best_only=True)
hist = model_1.fit(x_train, y_train, batch_size=32, epochs=20,validation_data=(x_valid, y_valid), callbacks=[checkpointer], verbose=2, shuffle=True)
		  
# load the weights that yielded the best validation accuracy
model_1.load_weights('model_1_CNN.hdf5')

# evaluate and print test accuracy
score = model_1.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 500)               512500
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 500)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               128256
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 653,870
# Trainable params: 653,870
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
#  - 11s - loss: 1.6410 - acc: 0.4017 - val_loss: 1.5407 - val_acc: 0.4708
#
# Epoch 00001: val_loss improved from inf to 1.54071, saving model to model_1_CNN.hdf5
# Epoch 2/20
#  - 10s - loss: 1.3165 - acc: 0.5289 - val_loss: 1.1784 - val_acc: 0.5864
#
# Epoch 00002: val_loss improved from 1.54071 to 1.17840, saving model to model_1_CNN.hdf5
# Epoch 3/20
#  - 10s - loss: 1.2081 - acc: 0.5796 - val_loss: 1.1845 - val_acc: 0.5824
#
# Epoch 00003: val_loss did not improve from 1.17840
# Epoch 4/20
#  - 10s - loss: 1.1577 - acc: 0.6014 - val_loss: 1.0715 - val_acc: 0.6416
#
# Epoch 00004: val_loss improved from 1.17840 to 1.07147, saving model to model_1_CNN.hdf5
# Epoch 5/20
#  - 10s - loss: 1.1370 - acc: 0.6136 - val_loss: 1.0490 - val_acc: 0.6310
#
# Epoch 00005: val_loss improved from 1.07147 to 1.04896, saving model to model_1_CNN.hdf5
# Epoch 6/20
#  - 10s - loss: 1.1439 - acc: 0.6156 - val_loss: 1.2212 - val_acc: 0.5826
#
# Epoch 00006: val_loss did not improve from 1.04896
# Epoch 7/20
#  - 10s - loss: 1.1561 - acc: 0.6141 - val_loss: 1.0408 - val_acc: 0.6526
#
# Epoch 00007: val_loss improved from 1.04896 to 1.04083, saving model to model_1_CNN.hdf5
# Epoch 8/20
#  - 10s - loss: 1.1709 - acc: 0.6081 - val_loss: 1.0989 - val_acc: 0.6222
#
# Epoch 00008: val_loss did not improve from 1.04083
# Epoch 9/20
#  - 10s - loss: 1.2107 - acc: 0.5963 - val_loss: 1.2204 - val_acc: 0.5878
#
# Epoch 00009: val_loss did not improve from 1.04083
# Epoch 10/20
